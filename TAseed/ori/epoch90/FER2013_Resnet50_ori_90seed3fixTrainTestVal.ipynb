# %% [markdown]
# Resnet-50 From Scratch

# %%
import numpy as np
import pandas as pd
import os 
inputFolder = '/content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth' 
for root, directories, filenames in os.walk(inputFolder): 
    for filename in filenames: print(os.path.join(root,filename))
# Out:
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/Best_Model_resnet50Scracth1again.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/Scracthfer2013.csv
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Best_Model_resnet50Scracth_tipe1.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Best_Model_resnet50Scracth_tipe4.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Best_Model_resnet50Scracth1again.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Best_Model_resnet50Scracth2.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Best_Model_resnet50ScracthSGD1.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Best_Model_resnet50AUGScracthadam3.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_Model_resnet50AUGScracthSGD1.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_Model_resnet50AUGScracthSGD2.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_Model_resnet50AUGScracthSGD3.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_Model_resnet50AUGScracthSGD1try2.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_Model_resnet50AUGScracthSGD4.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_Model_resnet50oriSGD1st.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_Model_resnet50SGD5stori.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_Model_resnet50editSGD5st.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_Model_resnet50editAdamst120epochBS128.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_Model_resnet50editAdamst120epochBS128_1.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_Model_resnet50editAdamst120epochBS128+aug:vf_2.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_Model_resnet50oriAdamst120epochBS128_aug1.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_Model_resnet50oriAdamst120epochBS128_noaug1.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_noAug_adam1_shuffalse1.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed_Aug_adam1_shuffalse1.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed_adam_shuffalse_noAug1.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed_SGD_shuffalse_Aug1.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed_SGD_shuffalse_Aug2.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed_Aug_adam2_shuffalse2.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed_SGD_60_shuffalse_Aug3.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed1_SGD_30_shuffalse_Aug1.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed2_SGD_30_shuffalse_Aug2.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed3_SGD_30_shuffalse_Aug3.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed3_Adam_30_shuffalse_Aug1.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed4_Adam_30_shuffalse_Aug2.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed5_Adam_30_shuffalse_Aug3.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed1_SGD_90_shuffalse_Aug1.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed3_SGD_90_shuffalse_Aug3.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed2_SGD_90_shuffalse_Aug2.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed4_SGD_90_shuffalse_Aug4.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed4_SGD_60_shuffalse_Aug4.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed5_SGD_90_shuffalse_Aug5.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed6_SGD_90_shuffalse_Aug6.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50oris_seed1_SGD_30_shuffalse_Aug1.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50oris_seed2_SGD_30_shuffalse_Aug2.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50oris_seed3_SGD_30_shuffalse_Aug3.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50oris_seed4_SGD_30_shuffalse_Aug4.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50oris_seed5_SGD_30_shuffalse_Aug5.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50oris_seed6_SGD_30_shuffalse_Aug6.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50oris_seed1_SGD_60_shuffalse_Aug1.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50oris_seed2_SGD_60_shuffalse_Aug2.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50oris_seed3_SGD_60_shuffalse_Aug3.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50oris_seed4_SGD_60_shuffalse_Aug4.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50oris_seed5_SGD_60_shuffalse_Aug5.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50oris_seed1_SGD_90_shuffalse_Aug1.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50oris_seed2_SGD_90_shuffalse_Aug2.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed_SGD_60_shuffalse_Aug3/saved_model.pb
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed_SGD_60_shuffalse_Aug3/keras_metadata.pb
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed_SGD_60_shuffalse_Aug3/variables/variables.data-00000-of-00001
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50edit_seed_SGD_60_shuffalse_Aug3/variables/variables.index
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/checkpoint/Best_Model_resnet50Scracth_oriyijungan1.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/checkpoint/Best_Model_resnet50Scracth_oriyijungan2.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/checkpoint/Best_Model_resnet50Scracth_oriyijungan3.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/checkpoint/Best_Model_resnet50Scracth_sena1.h5
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/checkpoint/Best_Model_resnet50oriScracth_sena2.h5

# %%
# %cd /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth
# Out:
# /content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth

# %%
#Create a directory to save our generated models.dasdas

#os.mkdir("./modelscracth")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-cf55f19f3613> in <module>()
#       3 #os.mkdir("./modelscracth")
#       4
# ----> 5 ls
#
# NameError: name 'ls' is not defined

# %%
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from tensorflow.keras.utils import plot_model
import tensorflow as tf
import random

tf.random.set_seed(42)
np.random.seed(42)

from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow
# %matplotlib inline

import keras.backend as K
K.set_image_data_format('channels_last')
K.set_learning_phase(1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:400: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '

# %%
#Define the identity block helper function.
def identity_block(X, f, filters, stage, block):
    """
    Implementation of the identity block
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    
    Returns:
    X -- output of the identity block, tensor of shape (n_H, n_W, n_C)
    """
    
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value. You'll need this later to add back to the main path. 
    X_shortcut = X
    
    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
    
   
    # Second component of main path
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path 
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation 
    X = Add()([X_shortcut,X])
    X = Activation("relu")(X)
        
    return X

# %%
def convolutional_block(X, f, filters, stage, block, s = 2):
    """
    Implementation of the convolutional block4
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    s -- Integer, specifying the stride to be used
    
    Returns:
    X -- output of the convolutional block, tensor of shape (n_H, n_W, n_C)
    """
    
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    # First component of main path 
    X = Conv2D(F1, (1, 1), strides = (s,s), name = conv_name_base + '2a',padding = 'valid', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
    
    # Second component of main path 
    X = Conv2D(F2, (f, f), strides = (1,1), name = conv_name_base + '2b',padding = 'same', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path 
    X = Conv2D(F3, (1, 1), strides = (1,1), name = conv_name_base + '2c',padding = 'valid', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    ##### SHORTCUT PATH #### 
    X_shortcut = Conv2D(F3, (1, 1), strides = (s,s), name = conv_name_base + '1',padding = 'valid', kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name_base + '1')(X_shortcut)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation 
    X = Add()([X_shortcut,X])
    X = Activation("relu")(X)
        
    return X

# %%
"""def ResNet50(input_shape = (48,48,1), classes = 7):
    """
    Implementation of the popular ResNet50 the following architecture:
    CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> IDBLOCK*2 -> CONVBLOCK -> IDBLOCK*3
    -> CONVBLOCK -> IDBLOCK*5 -> CONVBLOCK -> IDBLOCK*2 -> AVGPOOL -> TOPLAYER

    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns:
    model -- a Model() instance in Keras
    """
    
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    
    # Zero-Padding
    X = X_input
    # Stage 1

    X = Conv2D(8, (3, 3), strides = (1, 1), name = 'conv1', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    # removed maxpool
    #X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f = 3, filters = [32, 32, 128], stage = 2, block='a', s = 1)
    X = identity_block(X, 3, [32, 32, 128], stage=2, block='b')
    X = identity_block(X, 3, [32, 32, 128], stage=2, block='c')


    # Stage 3 
    X = convolutional_block(X, f = 3, filters = [64,64,256], stage = 3, block='a', s = 2)
    X = identity_block(X, 3, [64,64,256], stage=3, block='b')
    X = identity_block(X, 3, [64,64,256], stage=3, block='c')
    X = identity_block(X, 3, [64,64,256], stage=3, block='d')

    # Stage 4 
    X = convolutional_block(X, f = 3, filters = [128, 128, 512], stage = 4, block='a', s = 2)
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='d')
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='e')
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='f')

    # Stage 5 
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], stage = 5, block='a', s = 2)
    X = identity_block(X, 3, [256, 256, 1024], stage=5, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=5, block='c')

    # AVGPOOL . 
    X = AveragePooling2D((2,2), name='avg_pool')(X)
    
    # output layerds
    X = Flatten()(X)
    X = Dense(512, activation = 'relu', name='fc1024' , kernel_initializer = glorot_uniform(seed=0))(X)
    X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=0))(X)
    
    
    # Create model
    model = Model(inputs = X_input, outputs = X, name='ResNet50')

    return model"""

# %%
def ResNet50ori(input_shape = (48, 48, 1), classes = 7):
    """
    Implementation of the popular ResNet50 the following architecture:
    CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> IDBLOCK*2 -> CONVBLOCK -> IDBLOCK*3
    -> CONVBLOCK -> IDBLOCK*5 -> CONVBLOCK -> IDBLOCK*2 -> AVGPOOL -> TOPLAYER

    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns: dsdsf
    model -- a Model() instance in Keras
    """
    
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    
    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    # Stage 1
    X = Conv2D(64, (7, 7), strides = (2, 2), name = 'conv1', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], stage = 2, block='a', s = 1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')

    # Stage 3 (≈4 lines)
    X = convolutional_block(X, f = 3, filters = [128, 128, 512], stage = 3, block='a', s = 2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    # Stage 4 (≈6 lines)
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], stage = 4, block='a', s = 2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    # Stage 5 (≈3 lines)
    X = convolutional_block(X, f = 3, filters = [512, 512, 2048], stage = 5, block='a', s = 2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    # AVGPOOL (≈1 line). Use "X = AveragePooling2D(...)(X)"
    X = AveragePooling2D((2,2), name="avg_pool")(X)
    
    # output layer
    X = Flatten()(X)
    X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=0))(X)
    
    
    # Create model
    model = Model(inputs = X_input, outputs = X, name='ResNet50ori')

    return model

# %%
import cv2
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import CSVLogger, ModelCheckpoint, EarlyStopping
from keras.callbacks import ReduceLROnPlateau
 
dataset_path = '/content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/Scracthfer2013.csv'
image_size=(48,48)
#batch_size = 64

def load_fer2013():
    data = pd.read_csv(dataset_path)
    data = (data[data['pixels'].notnull()])
    pixels = data['pixels'].tolist()
    width, height = 48, 48
    faces = []
    for pixel_sequence in pixels:
        face = [int(pixel) for pixel in pixel_sequence.split(' ')]
        face = np.asarray(face).reshape(width, height)
        face = cv2.resize(face.astype('uint8'),image_size)
        faces.append(face.astype('float32'))
    faces = np.asarray(faces)
    faces = np.expand_dims(faces, -1)
    emotions = (data['emotion'])#.values
    return faces, emotions
 
def preprocess_input(x, v2=True):
    x = x.astype('float32')
    x = x / 255.0
    if v2:
        x = x - 0.5
        x = x * 2.0
    return x
 
faces, emotions = load_fer2013()
faces = preprocess_input(faces)
#xtrain, xtest,ytrain,ytest = train_test_split(faces, emotions,test_size=0.2,shuffle=True)
#Data Augumentation
data_generator = ImageDataGenerator(
                        rotation_range=10,
                        shear_range = 10,
                        width_shift_range=0.1,
                        height_shift_range=0.1,
                        zoom_range=.1,
                        horizontal_flip=True,
                        )
#data_generator = ImageDataGenerator( )

# %%
"""print ("validasi",x_val.shape)
print (y_val.shape)
print ("test",xtest.shape)
print (ytest.shape)
print ("train",xtrain.shape)
print (y_train.shape)"""
# Out:
# 'print ("validasi",x_val.shape)\nprint (y_val.shape)\nprint ("test",xtest.shape)\nprint (ytest.shape)\nprint ("train",xtrain.shape)\nprint (y_train.shape)'

# %%
train_ratio = 0.80
validation_ratio = 0.10
test_ratio = 0.10

# train is now 75% of the entire data set
# the _junk suffix means that we drop that variable completely # the _junk suffix means that we drop that variable completely
#x_train, x_test, y_train, y_test = train_test_split(dataX, dataY, test_size=1 - train_ratio)

xtrain, xtest, ytrain, ytest = train_test_split(faces, emotions, test_size=1 - train_ratio,random_state=42)

# test is now 10% of the initial data set
# validation is now 15% of the initial data set
#x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=test_ratio/(test_ratio + validation_ratio)) 
x_val, xtest, y_val, ytest = train_test_split(xtest, ytest, test_size=test_ratio/(test_ratio + validation_ratio), random_state=42) 

#print(xtrain, x_val, xtest)

"""X_train, X_test, y_train, y_test = train_test_split(faces, emotions, test_size=0.1, random_state=1)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.125, random_state=1) # 0.25 x 0.8 = 0.2"""
# Out:
# 'X_train, X_test, y_train, y_test = train_test_split(faces, emotions, test_size=0.1, random_state=1)\n\nX_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.125, random_state=1) # 0.25 x 0.8 = 0.2'

# %%
print ("validasi",x_val.shape)
print (y_val.shape)
print ("test",xtest.shape)
print (ytest.shape)
print ("train",xtrain.shape)
print (ytrain.shape)
# Out:
# validasi (3589, 48, 48, 1)
# (3589,)
# test (3589, 48, 48, 1)
# (3589,)
# train (28709, 48, 48, 1)
# (28709,)

# %%
#hyperparameter and callback
batch_size = 64
num_epochs = 90
input_shape = (48, 48, 1)
num_classes = 7

# %%
#Compile the model.gyg


from keras.optimizers import Adam, SGD
model = ResNet50ori(input_shape = (48, 48, 1), classes = 7)
optimizer = Adam(learning_rate=0.01)
model.compile(optimizer= optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "ResNet50ori"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 48, 48, 1)]  0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 54, 54, 1)    0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 24, 24, 64)   3200        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 24, 24, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 24, 24, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 11, 11, 64)   0           activation_49[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 11, 11, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 11, 11, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 11, 11, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 11, 11, 64)   36928       activation_50[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 11, 11, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 11, 11, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 11, 11, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 11, 11, 256)  16640       activation_51[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 11, 11, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 11, 11, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 11, 11, 256)  0           bn2a_branch1[0][0]
#                                                                  bn2a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 11, 11, 256)  0           add_16[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 11, 11, 64)   16448       activation_52[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 11, 11, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 11, 11, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 11, 11, 64)   36928       activation_53[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 11, 11, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 11, 11, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 11, 11, 256)  16640       activation_54[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 11, 11, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 11, 11, 256)  0           activation_52[0][0]
#                                                                  bn2b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 11, 11, 256)  0           add_17[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 11, 11, 64)   16448       activation_55[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 11, 11, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 11, 11, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 11, 11, 64)   36928       activation_56[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 11, 11, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 11, 11, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 11, 11, 256)  16640       activation_57[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 11, 11, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 11, 11, 256)  0           activation_55[0][0]
#                                                                  bn2c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 11, 11, 256)  0           add_18[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 6, 6, 128)    32896       activation_58[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 6, 6, 128)    512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 6, 6, 128)    0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 6, 6, 128)    147584      activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 6, 6, 128)    512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 6, 6, 128)    0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 6, 6, 512)    131584      activation_58[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 6, 6, 512)    66048       activation_60[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 6, 6, 512)    2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 6, 6, 512)    2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 6, 6, 512)    0           bn3a_branch1[0][0]
#                                                                  bn3a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 6, 6, 512)    0           add_19[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 6, 6, 128)    65664       activation_61[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 6, 6, 128)    512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 6, 6, 128)    0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 6, 6, 128)    147584      activation_62[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 6, 6, 128)    512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 6, 6, 128)    0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 6, 6, 512)    66048       activation_63[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 6, 6, 512)    2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 6, 6, 512)    0           activation_61[0][0]
#                                                                  bn3b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 6, 6, 512)    0           add_20[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 6, 6, 128)    65664       activation_64[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 6, 6, 128)    512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 6, 6, 128)    0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 6, 6, 128)    147584      activation_65[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 6, 6, 128)    512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 6, 6, 128)    0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 6, 6, 512)    66048       activation_66[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 6, 6, 512)    2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 6, 6, 512)    0           activation_64[0][0]
#                                                                  bn3c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 6, 6, 512)    0           add_21[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 6, 6, 128)    65664       activation_67[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 6, 6, 128)    512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 6, 6, 128)    0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 6, 6, 128)    147584      activation_68[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 6, 6, 128)    512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 6, 6, 128)    0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 6, 6, 512)    66048       activation_69[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 6, 6, 512)    2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 6, 6, 512)    0           activation_67[0][0]
#                                                                  bn3d_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 6, 6, 512)    0           add_22[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 3, 3, 256)    131328      activation_70[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 3, 3, 256)    1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 3, 3, 256)    0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 3, 3, 256)    590080      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 3, 3, 256)    1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 3, 3, 256)    0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 3, 3, 1024)   525312      activation_70[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 3, 3, 1024)   263168      activation_72[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 3, 3, 1024)   4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 3, 3, 1024)   0           bn4a_branch1[0][0]
#                                                                  bn4a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 3, 3, 1024)   0           add_23[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 3, 3, 256)    262400      activation_73[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 3, 3, 256)    1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 3, 3, 256)    0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 3, 3, 256)    590080      activation_74[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 3, 3, 256)    1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 3, 3, 256)    0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 3, 3, 1024)   263168      activation_75[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 3, 3, 1024)   0           activation_73[0][0]
#                                                                  bn4b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 3, 3, 1024)   0           add_24[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 3, 3, 256)    262400      activation_76[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 3, 3, 256)    1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 3, 3, 256)    0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 3, 3, 256)    590080      activation_77[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 3, 3, 256)    1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 3, 3, 256)    0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 3, 3, 1024)   263168      activation_78[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 3, 3, 1024)   0           activation_76[0][0]
#                                                                  bn4c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 3, 3, 1024)   0           add_25[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 3, 3, 256)    262400      activation_79[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 3, 3, 256)    1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 3, 3, 256)    0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 3, 3, 256)    590080      activation_80[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 3, 3, 256)    1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 3, 3, 256)    0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 3, 3, 1024)   263168      activation_81[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 3, 3, 1024)   0           activation_79[0][0]
#                                                                  bn4d_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 3, 3, 1024)   0           add_26[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 3, 3, 256)    262400      activation_82[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 3, 3, 256)    1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 3, 3, 256)    0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 3, 3, 256)    590080      activation_83[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 3, 3, 256)    1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 3, 3, 256)    0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 3, 3, 1024)   263168      activation_84[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 3, 3, 1024)   0           activation_82[0][0]
#                                                                  bn4e_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 3, 3, 1024)   0           add_27[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 3, 3, 256)    262400      activation_85[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 3, 3, 256)    1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 3, 3, 256)    0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 3, 3, 256)    590080      activation_86[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 3, 3, 256)    1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 3, 3, 256)    0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 3, 3, 1024)   263168      activation_87[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 3, 3, 1024)   0           activation_85[0][0]
#                                                                  bn4f_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 3, 3, 1024)   0           add_28[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 2, 2, 512)    524800      activation_88[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 2, 2, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 2, 2, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 2, 2, 512)    2359808     activation_89[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 2, 2, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 2, 2, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 2, 2, 2048)   2099200     activation_88[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 2, 2, 2048)   1050624     activation_90[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 2, 2, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 2, 2, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 2, 2, 2048)   0           bn5a_branch1[0][0]
#                                                                  bn5a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 2, 2, 2048)   0           add_29[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 2, 2, 512)    1049088     activation_91[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 2, 2, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 2, 2, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 2, 2, 512)    2359808     activation_92[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 2, 2, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 2, 2, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 2, 2, 2048)   1050624     activation_93[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 2, 2, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 2, 2, 2048)   0           activation_91[0][0]
#                                                                  bn5b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 2, 2, 2048)   0           add_30[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 2, 2, 512)    1049088     activation_94[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 2, 2, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 2, 2, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 2, 2, 512)    2359808     activation_95[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 2, 2, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 2, 2, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 2, 2, 2048)   1050624     activation_96[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 2, 2, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 2, 2, 2048)   0           activation_94[0][0]
#                                                                  bn5c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 2, 2, 2048)   0           add_31[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_97[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# fc7 (Dense)                     (None, 7)            14343       flatten_1[0][0]
# ==================================================================================================
# Total params: 23,595,783
# Trainable params: 23,542,663
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
history = model.fit(
    data_generator.flow(xtrain, ytrain,),
    steps_per_epoch=len(xtrain) / batch_size,
    epochs=num_epochs,
    shuffle=False, 
    verbose=1,
    validation_data= (x_val,y_val))
# Out:
# Epoch 1/90
# 448/448 [==============================] - 39s 62ms/step - loss: 3.8852 - accuracy: 0.2244 - val_loss: 1.9628 - val_accuracy: 0.2419
# Epoch 2/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.8164 - accuracy: 0.2419 - val_loss: 1.7989 - val_accuracy: 0.2471
# Epoch 3/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.7984 - accuracy: 0.2481 - val_loss: 1.8123 - val_accuracy: 0.2452
# Epoch 4/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.7867 - accuracy: 0.2483 - val_loss: 1.7795 - val_accuracy: 0.2561
# Epoch 5/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.7825 - accuracy: 0.2587 - val_loss: 1.7427 - val_accuracy: 0.2859
# Epoch 6/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.7589 - accuracy: 0.2763 - val_loss: 1.8189 - val_accuracy: 0.2850
# Epoch 7/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.7366 - accuracy: 0.2916 - val_loss: 1.8217 - val_accuracy: 0.3043
# Epoch 8/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.7072 - accuracy: 0.3013 - val_loss: 1.7141 - val_accuracy: 0.3224
# Epoch 9/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.6791 - accuracy: 0.3233 - val_loss: 1.6201 - val_accuracy: 0.3435
# Epoch 10/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.6518 - accuracy: 0.3408 - val_loss: 1.6335 - val_accuracy: 0.3642
# Epoch 11/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.6502 - accuracy: 0.3461 - val_loss: 2.3474 - val_accuracy: 0.2106
# Epoch 12/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.7389 - accuracy: 0.3035 - val_loss: 2.0850 - val_accuracy: 0.3396
# Epoch 13/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.6653 - accuracy: 0.3413 - val_loss: 2.2821 - val_accuracy: 0.3522
# Epoch 14/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.5964 - accuracy: 0.3747 - val_loss: 1.9752 - val_accuracy: 0.3628
# Epoch 15/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.5676 - accuracy: 0.3830 - val_loss: 9.4890 - val_accuracy: 0.2784
# Epoch 16/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.5812 - accuracy: 0.3784 - val_loss: 1.7243 - val_accuracy: 0.3912
# Epoch 17/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.5228 - accuracy: 0.4050 - val_loss: 19.5884 - val_accuracy: 0.2396
# Epoch 18/90
# 448/448 [==============================] - 26s 58ms/step - loss: 1.5272 - accuracy: 0.3968 - val_loss: 1.7808 - val_accuracy: 0.4391
# Epoch 19/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.5100 - accuracy: 0.4155 - val_loss: 2.6272 - val_accuracy: 0.3221
# Epoch 20/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.5089 - accuracy: 0.4081 - val_loss: 1.4293 - val_accuracy: 0.4422
# Epoch 21/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.4311 - accuracy: 0.4527 - val_loss: 1.3812 - val_accuracy: 0.4558
# Epoch 22/90
# 448/448 [==============================] - 26s 57ms/step - loss: 1.4058 - accuracy: 0.4549 - val_loss: 14.8918 - val_accuracy: 0.3185
# Epoch 23/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.4687 - accuracy: 0.4331 - val_loss: 1.3718 - val_accuracy: 0.4583
# Epoch 24/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.3920 - accuracy: 0.4616 - val_loss: 110.9411 - val_accuracy: 0.1594
# Epoch 25/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.4430 - accuracy: 0.4360 - val_loss: 1.3198 - val_accuracy: 0.4923
# Epoch 26/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.3704 - accuracy: 0.4707 - val_loss: 1.3818 - val_accuracy: 0.4667
# Epoch 27/90
# 448/448 [==============================] - 26s 58ms/step - loss: 1.3679 - accuracy: 0.4714 - val_loss: 1.3859 - val_accuracy: 0.4714
# Epoch 28/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.3280 - accuracy: 0.4892 - val_loss: 1.3385 - val_accuracy: 0.4935
# Epoch 29/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.3165 - accuracy: 0.4970 - val_loss: 1.3115 - val_accuracy: 0.5063
# Epoch 30/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.3205 - accuracy: 0.4892 - val_loss: 1.2805 - val_accuracy: 0.5155
# Epoch 31/90
# 448/448 [==============================] - 26s 58ms/step - loss: 1.2851 - accuracy: 0.5095 - val_loss: 1.4107 - val_accuracy: 0.4558
# Epoch 32/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.2892 - accuracy: 0.5062 - val_loss: 1.2796 - val_accuracy: 0.5068
# Epoch 33/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.2755 - accuracy: 0.5115 - val_loss: 1.2814 - val_accuracy: 0.5091
# Epoch 34/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.2710 - accuracy: 0.5044 - val_loss: 1.3454 - val_accuracy: 0.4703
# Epoch 35/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.2487 - accuracy: 0.5188 - val_loss: 1.2321 - val_accuracy: 0.5238
# Epoch 36/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.2431 - accuracy: 0.5329 - val_loss: 1.3124 - val_accuracy: 0.4887
# Epoch 37/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.2471 - accuracy: 0.5228 - val_loss: 1.4631 - val_accuracy: 0.4542
# Epoch 38/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.2538 - accuracy: 0.5173 - val_loss: 1.3066 - val_accuracy: 0.4809
# Epoch 39/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.2050 - accuracy: 0.5399 - val_loss: 1.1765 - val_accuracy: 0.5489
# Epoch 40/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.2013 - accuracy: 0.5412 - val_loss: 1.2481 - val_accuracy: 0.5319
# Epoch 41/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.2045 - accuracy: 0.5384 - val_loss: 1.2718 - val_accuracy: 0.5397
# Epoch 42/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.1781 - accuracy: 0.5447 - val_loss: 1.1900 - val_accuracy: 0.5500
# Epoch 43/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.1879 - accuracy: 0.5440 - val_loss: 1.2237 - val_accuracy: 0.5405
# Epoch 44/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.1890 - accuracy: 0.5434 - val_loss: 1.2313 - val_accuracy: 0.5405
# Epoch 45/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.2022 - accuracy: 0.5430 - val_loss: 1.2966 - val_accuracy: 0.5038
# Epoch 46/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.1934 - accuracy: 0.5456 - val_loss: 1.1959 - val_accuracy: 0.5525
# Epoch 47/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.1811 - accuracy: 0.5479 - val_loss: 1.1966 - val_accuracy: 0.5578
# Epoch 48/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.1615 - accuracy: 0.5561 - val_loss: 1.2882 - val_accuracy: 0.5261
# Epoch 49/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.1610 - accuracy: 0.5595 - val_loss: 1.1772 - val_accuracy: 0.5584
# Epoch 50/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.1583 - accuracy: 0.5658 - val_loss: 1.2049 - val_accuracy: 0.5472
# Epoch 51/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.1648 - accuracy: 0.5632 - val_loss: 1.1510 - val_accuracy: 0.5645
# Epoch 52/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.1394 - accuracy: 0.5783 - val_loss: 1.1411 - val_accuracy: 0.5645
# Epoch 53/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.1239 - accuracy: 0.5774 - val_loss: 1.1804 - val_accuracy: 0.5603
# Epoch 54/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.1320 - accuracy: 0.5688 - val_loss: 1.1352 - val_accuracy: 0.5787
# Epoch 55/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.1271 - accuracy: 0.5810 - val_loss: 1.1521 - val_accuracy: 0.5729
# Epoch 56/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.1180 - accuracy: 0.5759 - val_loss: 1.2123 - val_accuracy: 0.5500
# Epoch 57/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.1123 - accuracy: 0.5782 - val_loss: 1.1899 - val_accuracy: 0.5444
# Epoch 58/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.0961 - accuracy: 0.5798 - val_loss: 1.1459 - val_accuracy: 0.5812
# Epoch 59/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.1010 - accuracy: 0.5825 - val_loss: 1.1057 - val_accuracy: 0.5887
# Epoch 60/90
# 448/448 [==============================] - 24s 54ms/step - loss: 1.0949 - accuracy: 0.5862 - val_loss: 1.1246 - val_accuracy: 0.5751
# Epoch 61/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.0821 - accuracy: 0.5898 - val_loss: 1.3078 - val_accuracy: 0.5040
# Epoch 62/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.1043 - accuracy: 0.5864 - val_loss: 1.1759 - val_accuracy: 0.5715
# Epoch 63/90
# 448/448 [==============================] - 25s 55ms/step - loss: 1.0711 - accuracy: 0.5908 - val_loss: 1.1738 - val_accuracy: 0.5564
# Epoch 64/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.0706 - accuracy: 0.5948 - val_loss: 1.1510 - val_accuracy: 0.5729
# Epoch 65/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.0689 - accuracy: 0.5946 - val_loss: 1.1770 - val_accuracy: 0.5575
# Epoch 66/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.0811 - accuracy: 0.5880 - val_loss: 1.1565 - val_accuracy: 0.5695
# Epoch 67/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.0546 - accuracy: 0.6029 - val_loss: 1.1728 - val_accuracy: 0.5648
# Epoch 68/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.0911 - accuracy: 0.5825 - val_loss: 1.2732 - val_accuracy: 0.5249
# Epoch 69/90
# 448/448 [==============================] - 25s 57ms/step - loss: 1.0679 - accuracy: 0.5938 - val_loss: 1.1771 - val_accuracy: 0.5573
# Epoch 70/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.0560 - accuracy: 0.6008 - val_loss: 1.1813 - val_accuracy: 0.5386
# Epoch 71/90
# 448/448 [==============================] - 26s 58ms/step - loss: 1.0670 - accuracy: 0.5985 - val_loss: 1.0859 - val_accuracy: 0.5949
# Epoch 72/90
# 448/448 [==============================] - 25s 57ms/step - loss: 1.0675 - accuracy: 0.5985 - val_loss: 1.1070 - val_accuracy: 0.5790
# Epoch 73/90
# 448/448 [==============================] - 26s 58ms/step - loss: 1.0603 - accuracy: 0.6025 - val_loss: 1.1006 - val_accuracy: 0.5913
# Epoch 74/90
# 448/448 [==============================] - 26s 57ms/step - loss: 1.0365 - accuracy: 0.6101 - val_loss: 1.2646 - val_accuracy: 0.5768
# Epoch 75/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.0528 - accuracy: 0.6014 - val_loss: 1.1209 - val_accuracy: 0.5848
# Epoch 76/90
# 448/448 [==============================] - 27s 59ms/step - loss: 1.0567 - accuracy: 0.6049 - val_loss: 1.1343 - val_accuracy: 0.5717
# Epoch 77/90
# 448/448 [==============================] - 25s 57ms/step - loss: 1.1428 - accuracy: 0.5744 - val_loss: 1.1743 - val_accuracy: 0.5837
# Epoch 78/90
# 448/448 [==============================] - 25s 57ms/step - loss: 1.0635 - accuracy: 0.5899 - val_loss: 1.0961 - val_accuracy: 0.5840
# Epoch 79/90
# 448/448 [==============================] - 26s 57ms/step - loss: 1.0347 - accuracy: 0.6131 - val_loss: 1.1137 - val_accuracy: 0.5896
# Epoch 80/90
# 448/448 [==============================] - 25s 57ms/step - loss: 1.0618 - accuracy: 0.5941 - val_loss: 1.1833 - val_accuracy: 0.5745
# Epoch 81/90
# 448/448 [==============================] - 26s 57ms/step - loss: 1.1175 - accuracy: 0.5793 - val_loss: 1.0891 - val_accuracy: 0.5957
# Epoch 82/90
# 448/448 [==============================] - 25s 57ms/step - loss: 1.0274 - accuracy: 0.6107 - val_loss: 1.5679 - val_accuracy: 0.4154
# Epoch 83/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.1783 - accuracy: 0.5544 - val_loss: 1.0780 - val_accuracy: 0.5985
# Epoch 84/90
# 448/448 [==============================] - 26s 57ms/step - loss: 1.0418 - accuracy: 0.6076 - val_loss: 1.1075 - val_accuracy: 0.5857
# Epoch 85/90
# 448/448 [==============================] - 25s 56ms/step - loss: 1.0284 - accuracy: 0.6150 - val_loss: 1.0988 - val_accuracy: 0.5795
# Epoch 86/90
# 448/448 [==============================] - 25s 57ms/step - loss: 1.0512 - accuracy: 0.6031 - val_loss: 1.1191 - val_accuracy: 0.5840
# Epoch 87/90
# 448/448 [==============================] - 26s 57ms/step - loss: 1.0237 - accuracy: 0.6181 - val_loss: 1.0610 - val_accuracy: 0.5946
# Epoch 88/90
# 448/448 [==============================] - 26s 57ms/step - loss: 1.0308 - accuracy: 0.6137 - val_loss: 1.1215 - val_accuracy: 0.5882
# Epoch 89/90
# 448/448 [==============================] - 26s 57ms/step - loss: 0.9931 - accuracy: 0.6294 - val_loss: 1.0667 - val_accuracy: 0.5926
# Epoch 90/90
# 448/448 [==============================] - 27s 59ms/step - loss: 0.9806 - accuracy: 0.6275 - val_loss: 1.0792 - val_accuracy: 0.6082

# %%
import matplotlib.pyplot as plt 

model.save('/content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50oris_seed3_SGD_90_shuffalse_Aug3.h5')

#gffhgffkjkjdskjjkjkjkjhjhnnnhjhhuyghhgdasnuhgfgh
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
num_epochs = range(len(accuracy))
plt.plot(num_epochs, accuracy, 'r', label='Training acc')
plt.plot(num_epochs, val_accuracy, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.ylabel('accuracy')  
plt.xlabel('epoch')
plt.legend()
plt.figure()
plt.plot(num_epochs, loss, 'r', label='Training loss')
plt.plot(num_epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.ylabel('loss')  
plt.xlabel('epoch')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
testloss = model.evaluate(xtest, ytest) 
print("Test Loss " + str(testloss[0]))
print("Test Acc: " + str(testloss[1]))
trainloss = model.evaluate(xtrain, ytrain) 
print("Train Loss " + str(trainloss[0]))
print("Train Acc: " + str(trainloss[1]))

vallosz = model.evaluate(x_val, y_val) 
print("val Loss " + str(vallosz[0]))
print("val Acc: " + str(vallosz[1]))
# Out:
# 113/113 [==============================] - 2s 16ms/step - loss: 1.0494 - accuracy: 0.6144
# Test Loss 1.0494176149368286
# Test Acc: 0.6143772602081299
# 898/898 [==============================] - 13s 15ms/step - loss: 0.9519 - accuracy: 0.6446
# Train Loss 0.9519073963165283
# Train Acc: 0.6446062326431274
# 113/113 [==============================] - 2s 15ms/step - loss: 1.0792 - accuracy: 0.6082
# val Loss 1.0791531801223755
# val Acc: 0.6082473993301392

# %%
from keras.models import load_model
model_load = load_model('/content/drive/MyDrive/FER2013KaggleOri/fer2013/Resnet50Scracth/scratchcheckpoint/Fix_resnet50oris_seed3_SGD_90_shuffalse_Aug3.h5')

model_load.summary()
# Out:
# Model: "ResNet50ori"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 48, 48, 1)]  0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 54, 54, 1)    0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 24, 24, 64)   3200        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 24, 24, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 24, 24, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 11, 11, 64)   0           activation_49[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 11, 11, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 11, 11, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 11, 11, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 11, 11, 64)   36928       activation_50[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 11, 11, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 11, 11, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 11, 11, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 11, 11, 256)  16640       activation_51[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 11, 11, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 11, 11, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 11, 11, 256)  0           bn2a_branch1[0][0]
#                                                                  bn2a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 11, 11, 256)  0           add_16[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 11, 11, 64)   16448       activation_52[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 11, 11, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 11, 11, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 11, 11, 64)   36928       activation_53[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 11, 11, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 11, 11, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 11, 11, 256)  16640       activation_54[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 11, 11, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 11, 11, 256)  0           activation_52[0][0]
#                                                                  bn2b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 11, 11, 256)  0           add_17[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 11, 11, 64)   16448       activation_55[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 11, 11, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 11, 11, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 11, 11, 64)   36928       activation_56[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 11, 11, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 11, 11, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 11, 11, 256)  16640       activation_57[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 11, 11, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 11, 11, 256)  0           activation_55[0][0]
#                                                                  bn2c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 11, 11, 256)  0           add_18[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 6, 6, 128)    32896       activation_58[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 6, 6, 128)    512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 6, 6, 128)    0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 6, 6, 128)    147584      activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 6, 6, 128)    512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 6, 6, 128)    0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 6, 6, 512)    131584      activation_58[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 6, 6, 512)    66048       activation_60[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 6, 6, 512)    2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 6, 6, 512)    2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 6, 6, 512)    0           bn3a_branch1[0][0]
#                                                                  bn3a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 6, 6, 512)    0           add_19[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 6, 6, 128)    65664       activation_61[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 6, 6, 128)    512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 6, 6, 128)    0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 6, 6, 128)    147584      activation_62[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 6, 6, 128)    512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 6, 6, 128)    0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 6, 6, 512)    66048       activation_63[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 6, 6, 512)    2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 6, 6, 512)    0           activation_61[0][0]
#                                                                  bn3b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 6, 6, 512)    0           add_20[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 6, 6, 128)    65664       activation_64[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 6, 6, 128)    512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 6, 6, 128)    0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 6, 6, 128)    147584      activation_65[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 6, 6, 128)    512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 6, 6, 128)    0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 6, 6, 512)    66048       activation_66[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 6, 6, 512)    2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 6, 6, 512)    0           activation_64[0][0]
#                                                                  bn3c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 6, 6, 512)    0           add_21[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 6, 6, 128)    65664       activation_67[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 6, 6, 128)    512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 6, 6, 128)    0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 6, 6, 128)    147584      activation_68[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 6, 6, 128)    512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 6, 6, 128)    0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 6, 6, 512)    66048       activation_69[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 6, 6, 512)    2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 6, 6, 512)    0           activation_67[0][0]
#                                                                  bn3d_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 6, 6, 512)    0           add_22[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 3, 3, 256)    131328      activation_70[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 3, 3, 256)    1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 3, 3, 256)    0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 3, 3, 256)    590080      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 3, 3, 256)    1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 3, 3, 256)    0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 3, 3, 1024)   525312      activation_70[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 3, 3, 1024)   263168      activation_72[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 3, 3, 1024)   4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 3, 3, 1024)   0           bn4a_branch1[0][0]
#                                                                  bn4a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 3, 3, 1024)   0           add_23[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 3, 3, 256)    262400      activation_73[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 3, 3, 256)    1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 3, 3, 256)    0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 3, 3, 256)    590080      activation_74[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 3, 3, 256)    1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 3, 3, 256)    0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 3, 3, 1024)   263168      activation_75[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 3, 3, 1024)   0           activation_73[0][0]
#                                                                  bn4b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 3, 3, 1024)   0           add_24[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 3, 3, 256)    262400      activation_76[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 3, 3, 256)    1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 3, 3, 256)    0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 3, 3, 256)    590080      activation_77[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 3, 3, 256)    1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 3, 3, 256)    0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 3, 3, 1024)   263168      activation_78[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 3, 3, 1024)   0           activation_76[0][0]
#                                                                  bn4c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 3, 3, 1024)   0           add_25[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 3, 3, 256)    262400      activation_79[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 3, 3, 256)    1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 3, 3, 256)    0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 3, 3, 256)    590080      activation_80[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 3, 3, 256)    1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 3, 3, 256)    0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 3, 3, 1024)   263168      activation_81[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 3, 3, 1024)   0           activation_79[0][0]
#                                                                  bn4d_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 3, 3, 1024)   0           add_26[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 3, 3, 256)    262400      activation_82[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 3, 3, 256)    1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 3, 3, 256)    0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 3, 3, 256)    590080      activation_83[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 3, 3, 256)    1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 3, 3, 256)    0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 3, 3, 1024)   263168      activation_84[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 3, 3, 1024)   0           activation_82[0][0]
#                                                                  bn4e_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 3, 3, 1024)   0           add_27[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 3, 3, 256)    262400      activation_85[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 3, 3, 256)    1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 3, 3, 256)    0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 3, 3, 256)    590080      activation_86[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 3, 3, 256)    1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 3, 3, 256)    0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 3, 3, 1024)   263168      activation_87[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 3, 3, 1024)   0           activation_85[0][0]
#                                                                  bn4f_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 3, 3, 1024)   0           add_28[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 2, 2, 512)    524800      activation_88[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 2, 2, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 2, 2, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 2, 2, 512)    2359808     activation_89[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 2, 2, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 2, 2, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 2, 2, 2048)   2099200     activation_88[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 2, 2, 2048)   1050624     activation_90[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 2, 2, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 2, 2, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 2, 2, 2048)   0           bn5a_branch1[0][0]
#                                                                  bn5a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 2, 2, 2048)   0           add_29[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 2, 2, 512)    1049088     activation_91[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 2, 2, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 2, 2, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 2, 2, 512)    2359808     activation_92[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 2, 2, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 2, 2, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 2, 2, 2048)   1050624     activation_93[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 2, 2, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 2, 2, 2048)   0           activation_91[0][0]
#                                                                  bn5b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 2, 2, 2048)   0           add_30[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 2, 2, 512)    1049088     activation_94[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 2, 2, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 2, 2, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 2, 2, 512)    2359808     activation_95[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 2, 2, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 2, 2, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 2, 2, 2048)   1050624     activation_96[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 2, 2, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 2, 2, 2048)   0           activation_94[0][0]
#                                                                  bn5c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 2, 2, 2048)   0           add_31[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_97[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# fc7 (Dense)                     (None, 7)            14343       flatten_1[0][0]
# ==================================================================================================
# Total params: 23,595,783
# Trainable params: 23,542,663
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
#loss,acc = model_load.evaluate(xtrain,ytrain)
"""print("loss:",loss)
print("acc:",acc)kjjkj"""


testdatamodel = model_load.evaluate(xtest, ytest) 
print("Test Loss " + str(testdatamodel[0]))
print("Test Acc: " + str(testdatamodel[1]))

traindata = model_load.evaluate(xtrain, ytrain) 
print("Train Loss " + str(traindata[0]))
print("Train Acc: " + str(traindata[1]))

valdata = model_load.evaluate(x_val, y_val) 
print("Val Loss " + str(valdata[0]))
print("Val Acc: " + str(valdata[1]))
# Out:
# 113/113 [==============================] - 5s 15ms/step - loss: 1.0494 - accuracy: 0.6144
# Test Loss 1.0494176149368286
# Test Acc: 0.6143772602081299
# 898/898 [==============================] - 13s 15ms/step - loss: 0.9519 - accuracy: 0.6446
# Train Loss 0.9519073963165283
# Train Acc: 0.6446062326431274
# 113/113 [==============================] - 2s 15ms/step - loss: 1.0792 - accuracy: 0.6082
# Val Loss 1.0791531801223755
# Val Acc: 0.6082473993301392

# %%
print (x_val.shape)
print (y_val.shape)
print (xtest.shape)
print (ytest.shape)
print (xtrain.shape)
print (ytrain.shape)
# Out:
# (3589, 48, 48, 1)
# (3589,)
# (3589, 48, 48, 1)
# (3589,)
# (28709, 48, 48, 1)
# (28709,)

# %%
from sklearn.metrics import confusion_matrix, classification_report
from mlxtend.plotting import plot_confusion_matrix

#y_pred = model_load.predict(xtest)g

test_prob = model_load.predict(xtest)
test_pred = np.argmax(test_prob, axis=1)
test_accuracy = np.mean(test_pred == ytest)

print(test_accuracy)
# Out:
# 0.6143772638617999

# %%
emotions = {0: 'Angry', 1: 'Disgust', 2: 'Fear', 3: 'Happy', 4: 'Sad', 5: 'Surprise', 6: 'Neutral'}

# %%
conf_mat = confusion_matrix(ytest, test_pred)

pd.DataFrame(conf_mat, columns=emotions.values(), index=emotions.values())

#ghg

fig, ax = plot_confusion_matrix(conf_mat=conf_mat,show_normed=True,show_absolute=False,figsize=(8, 8))
fig.show()

# %%
print(classification_report(ytest, test_pred, target_names=emotions.values()))
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.52      0.50      0.51       480
#      Disgust       0.71      0.28      0.40        60
#         Fear       0.56      0.24      0.33       515
#        Happy       0.82      0.84      0.83       883
#          Sad       0.47      0.53      0.50       597
#     Surprise       0.65      0.81      0.72       397
#      Neutral       0.55      0.67      0.60       657
#
#     accuracy                           0.61      3589
#    macro avg       0.61      0.55      0.56      3589
# weighted avg       0.61      0.61      0.60      3589
